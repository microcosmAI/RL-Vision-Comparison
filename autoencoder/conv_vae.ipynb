# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
import torchvision
import numpy as np
import matplotlib.pyplot as plt; plt.rcParams['figure.dpi'] = 200
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os

# %%
device = "mps"

# %%
def reparameterize(mu, logvar):
    std = torch.exp(0.5*logvar)
    eps = torch.randn_like(std)
    return mu + eps*std

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.flatten = nn.Flatten()
        self.fc_mu = nn.Linear(128 * 16 * 16, 300)  # For mean
        self.fc_logvar = nn.Linear(128 * 16 * 16, 300)  # For log variance

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = self.flatten(x)
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        self.fc = nn.Linear(300, 128 * 16 * 16)
        self.conv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv2 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.conv3 = nn.ConvTranspose2d(32, 3, kernel_size=2, stride=2)

    def forward(self, x):
        x = self.fc(x)
        x = F.relu(x)
        x = x.view(-1, 128, 16, 16)  # Reshape to match the encoder's last conv layer output shape
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv3(x))  # Use sigmoid for the last layer if images are normalized between [0,1]
        return x

class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()

    def forward(self, x):
        mu, logvar = self.encoder(x)
        z = reparameterize(mu, logvar)
        return self.decoder(z), mu, logvar

# %%
from torch.utils.tensorboard import SummaryWriter
def train(vae, data, epochs=20, initial_lr=0.001, anneal_factor=0.5, anneal_epochs=10, name="vae_training"):
    opt = torch.optim.Adam(vae.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size=anneal_epochs, gamma=anneal_factor)
    
    writer = SummaryWriter(log_dir=f"results/{name}")  # Create a SummaryWriter object for TensorBoard
    
    for epoch in range(epochs):
        losses = 0
        for x in data:
            x = x.to(device)  # Assuming 'device' is defined (e.g., 'cuda' or 'cpu')
            opt.zero_grad()
            x_hat, mu, logvar = vae(x)
            # Reconstruction loss
            recon_loss = F.mse_loss(x_hat, x, reduction='sum')
            # KL divergence
            kld = -0.05 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
            # Total loss
            loss = recon_loss + kld
            losses += loss.item()
            loss.backward()
            opt.step()
        
        scheduler.step()  # Update learning rate
        
        # Write loss and learning rate to TensorBoard
        writer.add_scalar('Reconstruction Loss', recon_loss.item(), epoch)
        writer.add_scalar('KL Divergence', kld.item(), epoch)
        writer.add_scalar('Learning Rate', scheduler.get_lr()[0], epoch)
        
        print(f"Epoch {epoch+1}, Loss: {loss.item()}, Learning Rate: {scheduler.get_lr()[0]}")
    
    writer.close()  # Close the SummaryWriter
    
    return vae

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

def imshow(img, name):
    """
    Helper function to unnormalize and display an image
    """
    if "resultImages" not in os.listdir():
        os.mkdir("resultImages")
    img = img / 2 + 0.5  # unnormalize if you used normalization in your transform
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.imsave(f"resultImages/{name}.png", np.transpose(npimg, (1, 2, 0)))

def show_images(autoencoder, data_set, device, env):
    """
    Show original and reconstructed images.
    
    Parameters:
    - autoencoder: the trained autoencoder model.
    - data_loader: PyTorch DataLoader containing the dataset.
    - device: PyTorch device to use ('cuda' or 'cpu').
    """
    # Get a batch of images
    image = data_set[random.randint(0, len(data_set))]
    images = image.unsqueeze(0)

    # Move images to the device
    images = images.to(device)

    # Forward pass through the autoencoder
    reconstructed, _, _ = autoencoder(images) # detach to avoid tracking history in autograd
    reconstructed = reconstructed.detach()

    # Move images back to cpu for visualization
    images = images.cpu()
    reconstructed = reconstructed.cpu()

    # Display original images
    print("Original Images")
    imshow(torchvision.utils.make_grid(images), f"{env}_original")

    # Display reconstructed images
    print("Reconstructed Images")
    imshow(torchvision.utils.make_grid(reconstructed), f"{env}_reconstructed")

# %%
num_epochs = 90
device = "mps"

class Dataset(Dataset):
    def __init__(self, directory, transform=None):
        self.directory = directory
        self.transform = transform
        self.images = [os.path.join(directory, img) for img in os.listdir(directory)]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize images to a fixed size
    transforms.ToTensor(),        # Convert images to PyTorch tensors
])

for env in os.listdir("images"):
# for env in ["BoxingNoFrameskip-v4"]:
    dataset = Dataset(directory=f'images/{env}', transform=transform)
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

    autoencoder = VAE().to(device)
    autoencoder = train(autoencoder, dataloader, num_epochs, name=env)

    test_dataset = Dataset(directory=f'images/{env}', transform=transform)

    show_images(autoencoder, test_dataset, device, str(env))

    torch.save(autoencoder.state_dict(), f"models/{env}_vae_{100}.pth")
# Out:
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.not_equal_zero' op Invalid configuration for the following reasons: Tensor dimensions N1D1C32H1W32768 are not within supported range, N[1-65536]D[1-16384]C[1-65536]H[1-16384]W[1-16384].
# loc("mps_select"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/0032d1ee-80fd-11ee-8227-6aecfccc70fe/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":294:0)): error: 'anec.not_equal_zero' op Invalid configuration for the following reasons: Tensor dimensions N1D1C16H1W32768 are not within supported range, N[1-65536]D[1-16384]C[1-65536]H[1-16384]W[1-16384].
# /Users/cowolff/miniconda3/envs/Ray/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:389: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Epoch 1, Loss: 26609.515625, Learning Rate: 0.001
# Epoch 2, Loss: 3918.392822265625, Learning Rate: 0.001
# Epoch 3, Loss: 2876.921875, Learning Rate: 0.001
# Epoch 4, Loss: 2764.923828125, Learning Rate: 0.001
# Epoch 5, Loss: 2110.52197265625, Learning Rate: 0.001
# Epoch 6, Loss: 1879.6595458984375, Learning Rate: 0.001
# Epoch 7, Loss: 1611.83935546875, Learning Rate: 0.001
# Epoch 8, Loss: 1319.81982421875, Learning Rate: 0.001
# Epoch 9, Loss: 1376.802490234375, Learning Rate: 0.001
# Epoch 10, Loss: 1089.243896484375, Learning Rate: 0.00025
# Epoch 11, Loss: 1210.3438720703125, Learning Rate: 0.0005
# Epoch 12, Loss: 1196.037841796875, Learning Rate: 0.0005
# Epoch 13, Loss: 1188.4696044921875, Learning Rate: 0.0005
# Epoch 14, Loss: 1046.5050048828125, Learning Rate: 0.0005
# Epoch 15, Loss: 993.2295532226562, Learning Rate: 0.0005
# Epoch 16, Loss: 1021.7545776367188, Learning Rate: 0.0005
# Epoch 17, Loss: 961.159423828125, Learning Rate: 0.0005
# Epoch 18, Loss: 965.881103515625, Learning Rate: 0.0005
# Epoch 19, Loss: 1014.5492553710938, Learning Rate: 0.0005
# Epoch 20, Loss: 921.1351928710938, Learning Rate: 0.000125
# Epoch 21, Loss: 905.4727172851562, Learning Rate: 0.00025
# Epoch 22, Loss: 933.485107421875, Learning Rate: 0.00025
# Epoch 23, Loss: 865.8386840820312, Learning Rate: 0.00025
# Epoch 24, Loss: 882.030029296875, Learning Rate: 0.00025
# Epoch 25, Loss: 878.1376953125, Learning Rate: 0.00025
# Epoch 26, Loss: 866.2959594726562, Learning Rate: 0.00025
# Epoch 27, Loss: 792.2373657226562, Learning Rate: 0.00025
# Epoch 28, Loss: 874.8651123046875, Learning Rate: 0.00025
# Epoch 29, Loss: 900.298583984375, Learning Rate: 0.00025
# Epoch 30, Loss: 914.01171875, Learning Rate: 6.25e-05
# Epoch 31, Loss: 884.345703125, Learning Rate: 0.000125
# Epoch 32, Loss: 759.0008544921875, Learning Rate: 0.000125
# Epoch 33, Loss: 789.0584716796875, Learning Rate: 0.000125
# Epoch 34, Loss: 843.2703857421875, Learning Rate: 0.000125
# Epoch 35, Loss: 797.4253540039062, Learning Rate: 0.000125
# Epoch 36, Loss: 943.1322021484375, Learning Rate: 0.000125
# Epoch 37, Loss: 788.9470825195312, Learning Rate: 0.000125
# Epoch 38, Loss: 786.1387329101562, Learning Rate: 0.000125
# Epoch 39, Loss: 757.275390625, Learning Rate: 0.000125
# Epoch 40, Loss: 791.0093994140625, Learning Rate: 3.125e-05
# Epoch 41, Loss: 835.5848388671875, Learning Rate: 6.25e-05
# Epoch 42, Loss: 765.4053955078125, Learning Rate: 6.25e-05
# Epoch 43, Loss: 824.3964233398438, Learning Rate: 6.25e-05
# Epoch 44, Loss: 751.2740478515625, Learning Rate: 6.25e-05
# Epoch 45, Loss: 721.260009765625, Learning Rate: 6.25e-05
# Epoch 46, Loss: 810.6168823242188, Learning Rate: 6.25e-05
# Epoch 47, Loss: 780.414306640625, Learning Rate: 6.25e-05
# Epoch 48, Loss: 812.3931274414062, Learning Rate: 6.25e-05
# Epoch 49, Loss: 750.0031127929688, Learning Rate: 6.25e-05
# Epoch 50, Loss: 748.298095703125, Learning Rate: 1.5625e-05
# Epoch 51, Loss: 769.9546508789062, Learning Rate: 3.125e-05
# Epoch 52, Loss: 722.82421875, Learning Rate: 3.125e-05
# Epoch 53, Loss: 790.9921875, Learning Rate: 3.125e-05
# Epoch 54, Loss: 793.205322265625, Learning Rate: 3.125e-05
# Epoch 55, Loss: 832.4498901367188, Learning Rate: 3.125e-05
# Epoch 56, Loss: 775.2756958007812, Learning Rate: 3.125e-05
# Epoch 57, Loss: 775.3908081054688, Learning Rate: 3.125e-05
# Epoch 58, Loss: 729.4479370117188, Learning Rate: 3.125e-05
# Epoch 59, Loss: 703.5787963867188, Learning Rate: 3.125e-05
# Epoch 60, Loss: 785.75634765625, Learning Rate: 7.8125e-06
# Epoch 61, Loss: 795.180908203125, Learning Rate: 1.5625e-05
# Epoch 62, Loss: 719.770751953125, Learning Rate: 1.5625e-05
# Epoch 63, Loss: 781.7178344726562, Learning Rate: 1.5625e-05
# Epoch 64, Loss: 783.702392578125, Learning Rate: 1.5625e-05
# Epoch 65, Loss: 703.310546875, Learning Rate: 1.5625e-05
# Epoch 66, Loss: 690.65380859375, Learning Rate: 1.5625e-05
# Epoch 67, Loss: 723.7469482421875, Learning Rate: 1.5625e-05
# Epoch 68, Loss: 764.3991088867188, Learning Rate: 1.5625e-05
# Epoch 69, Loss: 704.9741821289062, Learning Rate: 1.5625e-05
# Epoch 70, Loss: 752.8898315429688, Learning Rate: 3.90625e-06
# Epoch 71, Loss: 755.0013427734375, Learning Rate: 7.8125e-06
# Epoch 72, Loss: 728.175537109375, Learning Rate: 7.8125e-06
# Epoch 73, Loss: 772.8543701171875, Learning Rate: 7.8125e-06
# Epoch 74, Loss: 773.9171142578125, Learning Rate: 7.8125e-06
# Epoch 75, Loss: 769.0891723632812, Learning Rate: 7.8125e-06
# Epoch 76, Loss: 674.734130859375, Learning Rate: 7.8125e-06
# Epoch 77, Loss: 786.367431640625, Learning Rate: 7.8125e-06
# Epoch 78, Loss: 710.8582153320312, Learning Rate: 7.8125e-06
# Epoch 79, Loss: 756.9066772460938, Learning Rate: 7.8125e-06
# Epoch 80, Loss: 792.6967163085938, Learning Rate: 1.953125e-06
# Epoch 81, Loss: 731.6769409179688, Learning Rate: 3.90625e-06
# Epoch 82, Loss: 701.1893310546875, Learning Rate: 3.90625e-06
# Epoch 83, Loss: 766.6436157226562, Learning Rate: 3.90625e-06
# Epoch 84, Loss: 715.45947265625, Learning Rate: 3.90625e-06
# Epoch 85, Loss: 827.8264770507812, Learning Rate: 3.90625e-06
# Epoch 86, Loss: 707.3082885742188, Learning Rate: 3.90625e-06
# Epoch 87, Loss: 707.5753784179688, Learning Rate: 3.90625e-06
# Epoch 88, Loss: 759.7672729492188, Learning Rate: 3.90625e-06
# Epoch 89, Loss: 670.31591796875, Learning Rate: 3.90625e-06
# Epoch 90, Loss: 748.2756958007812, Learning Rate: 9.765625e-07
# Original Images
# Reconstructed Images
# Epoch 1, Loss: 3992.076904296875, Learning Rate: 0.001
# Epoch 2, Loss: 3300.6328125, Learning Rate: 0.001
# Epoch 3, Loss: 2613.746826171875, Learning Rate: 0.001
# Epoch 4, Loss: 2497.482421875, Learning Rate: 0.001
# Epoch 5, Loss: 2069.410888671875, Learning Rate: 0.001
# Epoch 6, Loss: 2076.337158203125, Learning Rate: 0.001
# Epoch 7, Loss: 1693.564208984375, Learning Rate: 0.001
# Epoch 8, Loss: 1613.1123046875, Learning Rate: 0.001
# Epoch 9, Loss: 1441.313720703125, Learning Rate: 0.001
# Epoch 10, Loss: 1421.591796875, Learning Rate: 0.00025
# Epoch 11, Loss: 1219.0540771484375, Learning Rate: 0.0005
# Epoch 12, Loss: 1265.3502197265625, Learning Rate: 0.0005
# Epoch 13, Loss: 1192.5845947265625, Learning Rate: 0.0005
# Epoch 14, Loss: 1152.32177734375, Learning Rate: 0.0005
# Epoch 15, Loss: 1121.3734130859375, Learning Rate: 0.0005
# Epoch 16, Loss: 1107.66552734375, Learning Rate: 0.0005
# Epoch 17, Loss: 1170.8524169921875, Learning Rate: 0.0005
# Epoch 18, Loss: 1035.6055908203125, Learning Rate: 0.0005
# Epoch 19, Loss: 963.159423828125, Learning Rate: 0.0005
# Epoch 20, Loss: 1037.6273193359375, Learning Rate: 0.000125
# Epoch 21, Loss: 1008.7200927734375, Learning Rate: 0.00025
# Epoch 22, Loss: 964.9974365234375, Learning Rate: 0.00025
# Epoch 23, Loss: 1008.0737915039062, Learning Rate: 0.00025
# Epoch 24, Loss: 931.3829956054688, Learning Rate: 0.00025
# Epoch 25, Loss: 934.5217895507812, Learning Rate: 0.00025
# Epoch 26, Loss: 970.001220703125, Learning Rate: 0.00025
# Epoch 27, Loss: 869.4630126953125, Learning Rate: 0.00025
# Epoch 28, Loss: 931.7442016601562, Learning Rate: 0.00025
# Epoch 29, Loss: 929.6788940429688, Learning Rate: 0.00025
# Epoch 30, Loss: 844.27490234375, Learning Rate: 6.25e-05
# Epoch 31, Loss: 880.75390625, Learning Rate: 0.000125
# Epoch 32, Loss: 932.6212158203125, Learning Rate: 0.000125
# Epoch 33, Loss: 830.9280395507812, Learning Rate: 0.000125
# Epoch 34, Loss: 870.580810546875, Learning Rate: 0.000125
# Epoch 35, Loss: 914.4517822265625, Learning Rate: 0.000125
# Epoch 36, Loss: 805.71337890625, Learning Rate: 0.000125
# Epoch 37, Loss: 944.8466186523438, Learning Rate: 0.000125
# Epoch 38, Loss: 855.0853271484375, Learning Rate: 0.000125
# Epoch 39, Loss: 821.8176879882812, Learning Rate: 0.000125
# Epoch 40, Loss: 795.7892456054688, Learning Rate: 3.125e-05
# Epoch 41, Loss: 809.3060913085938, Learning Rate: 6.25e-05
# Epoch 42, Loss: 834.0962524414062, Learning Rate: 6.25e-05
# Epoch 43, Loss: 860.0106811523438, Learning Rate: 6.25e-05
# Epoch 44, Loss: 813.0508422851562, Learning Rate: 6.25e-05
# Epoch 45, Loss: 755.310791015625, Learning Rate: 6.25e-05
# Epoch 46, Loss: 789.9029541015625, Learning Rate: 6.25e-05
# Epoch 47, Loss: 837.6640625, Learning Rate: 6.25e-05
# Epoch 48, Loss: 744.4956665039062, Learning Rate: 6.25e-05
# Epoch 49, Loss: 824.499755859375, Learning Rate: 6.25e-05
# Epoch 50, Loss: 780.173583984375, Learning Rate: 1.5625e-05
# Epoch 51, Loss: 824.7301025390625, Learning Rate: 3.125e-05
# Epoch 52, Loss: 753.8218383789062, Learning Rate: 3.125e-05
# Epoch 53, Loss: 774.74365234375, Learning Rate: 3.125e-05
# Epoch 54, Loss: 831.3405151367188, Learning Rate: 3.125e-05
# Epoch 55, Loss: 776.5096435546875, Learning Rate: 3.125e-05
# Epoch 56, Loss: 832.6956176757812, Learning Rate: 3.125e-05
# Epoch 57, Loss: 788.178955078125, Learning Rate: 3.125e-05
# Epoch 58, Loss: 789.3640747070312, Learning Rate: 3.125e-05
# Epoch 59, Loss: 835.16064453125, Learning Rate: 3.125e-05
# Epoch 60, Loss: 782.9080810546875, Learning Rate: 7.8125e-06
# Epoch 61, Loss: 792.7857055664062, Learning Rate: 1.5625e-05
# Epoch 62, Loss: 776.491455078125, Learning Rate: 1.5625e-05
# Epoch 63, Loss: 817.7996826171875, Learning Rate: 1.5625e-05
# Epoch 64, Loss: 817.975341796875, Learning Rate: 1.5625e-05
# Epoch 65, Loss: 803.962158203125, Learning Rate: 1.5625e-05
# Epoch 66, Loss: 775.7254028320312, Learning Rate: 1.5625e-05
# Epoch 67, Loss: 783.7590942382812, Learning Rate: 1.5625e-05
# Epoch 68, Loss: 781.4681396484375, Learning Rate: 1.5625e-05
# Epoch 69, Loss: 845.4107666015625, Learning Rate: 1.5625e-05
# Epoch 70, Loss: 725.4633178710938, Learning Rate: 3.90625e-06
# Epoch 71, Loss: 787.4497680664062, Learning Rate: 7.8125e-06
# Epoch 72, Loss: 748.50048828125, Learning Rate: 7.8125e-06
# Epoch 73, Loss: 793.781982421875, Learning Rate: 7.8125e-06
# Epoch 74, Loss: 734.0594482421875, Learning Rate: 7.8125e-06
# Epoch 75, Loss: 782.1572265625, Learning Rate: 7.8125e-06
# Epoch 76, Loss: 822.707275390625, Learning Rate: 7.8125e-06
# Epoch 77, Loss: 814.7042236328125, Learning Rate: 7.8125e-06
# Epoch 78, Loss: 762.0587768554688, Learning Rate: 7.8125e-06
# Epoch 79, Loss: 822.1211547851562, Learning Rate: 7.8125e-06
# Epoch 80, Loss: 800.7841796875, Learning Rate: 1.953125e-06
# Epoch 81, Loss: 776.014404296875, Learning Rate: 3.90625e-06
# Epoch 82, Loss: 800.9147338867188, Learning Rate: 3.90625e-06
# Epoch 83, Loss: 735.4425659179688, Learning Rate: 3.90625e-06
# Epoch 84, Loss: 804.3052368164062, Learning Rate: 3.90625e-06
# Epoch 85, Loss: 790.5035400390625, Learning Rate: 3.90625e-06
# Epoch 86, Loss: 773.4085693359375, Learning Rate: 3.90625e-06
# Epoch 87, Loss: 795.2279663085938, Learning Rate: 3.90625e-06
# Epoch 88, Loss: 773.5421142578125, Learning Rate: 3.90625e-06
# Epoch 89, Loss: 819.9337768554688, Learning Rate: 3.90625e-06
# Epoch 90, Loss: 813.6876220703125, Learning Rate: 9.765625e-07
# Original Images
# Reconstructed Images
# Epoch 1, Loss: 6116.2841796875, Learning Rate: 0.001
# Epoch 2, Loss: 633.779052734375, Learning Rate: 0.001
# Epoch 3, Loss: 420.0129089355469, Learning Rate: 0.001
# Epoch 4, Loss: 876.7498168945312, Learning Rate: 0.001
# Epoch 5, Loss: 393.095458984375, Learning Rate: 0.001
# Epoch 6, Loss: 327.2171630859375, Learning Rate: 0.001
# Epoch 7, Loss: 496.53448486328125, Learning Rate: 0.001
# Epoch 8, Loss: 805.24169921875, Learning Rate: 0.001
# Epoch 9, Loss: 285.7299499511719, Learning Rate: 0.001
# Epoch 10, Loss: 828.2982788085938, Learning Rate: 0.00025
# Epoch 11, Loss: 297.98089599609375, Learning Rate: 0.0005
# Epoch 12, Loss: 323.6588439941406, Learning Rate: 0.0005
# Epoch 13, Loss: 294.18743896484375, Learning Rate: 0.0005
# Epoch 14, Loss: 481.97344970703125, Learning Rate: 0.0005
# Epoch 15, Loss: 258.6017150878906, Learning Rate: 0.0005
# Epoch 16, Loss: 379.88983154296875, Learning Rate: 0.0005
# Epoch 17, Loss: 272.093017578125, Learning Rate: 0.0005
# Epoch 18, Loss: 479.7777099609375, Learning Rate: 0.0005
# Epoch 19, Loss: 325.7455749511719, Learning Rate: 0.0005
# Epoch 20, Loss: 412.2633972167969, Learning Rate: 0.000125
# Epoch 21, Loss: 441.15252685546875, Learning Rate: 0.00025
# Epoch 22, Loss: 334.423095703125, Learning Rate: 0.00025
# Epoch 23, Loss: 255.62548828125, Learning Rate: 0.00025
# Epoch 24, Loss: 215.6058349609375, Learning Rate: 0.00025
# Epoch 25, Loss: 245.5804443359375, Learning Rate: 0.00025
# Epoch 26, Loss: 242.54331970214844, Learning Rate: 0.00025
# Epoch 27, Loss: 214.82614135742188, Learning Rate: 0.00025
# Epoch 28, Loss: 356.31927490234375, Learning Rate: 0.00025
# Epoch 29, Loss: 304.475830078125, Learning Rate: 0.00025
# Epoch 30, Loss: 200.69346618652344, Learning Rate: 6.25e-05
# Epoch 31, Loss: 325.31201171875, Learning Rate: 0.000125
# Epoch 32, Loss: 341.76348876953125, Learning Rate: 0.000125
# Epoch 33, Loss: 243.66908264160156, Learning Rate: 0.000125
# Epoch 34, Loss: 204.0240936279297, Learning Rate: 0.000125
# Epoch 35, Loss: 207.52340698242188, Learning Rate: 0.000125
# Epoch 36, Loss: 286.5810852050781, Learning Rate: 0.000125
# Epoch 37, Loss: 195.4063720703125, Learning Rate: 0.000125
# Epoch 38, Loss: 194.485595703125, Learning Rate: 0.000125
# Epoch 39, Loss: 280.5392761230469, Learning Rate: 0.000125
# Epoch 40, Loss: 222.5325164794922, Learning Rate: 3.125e-05
# Epoch 41, Loss: 217.67604064941406, Learning Rate: 6.25e-05
# Epoch 42, Loss: 281.87335205078125, Learning Rate: 6.25e-05
# Epoch 43, Loss: 268.2722473144531, Learning Rate: 6.25e-05
# Epoch 44, Loss: 253.43296813964844, Learning Rate: 6.25e-05
# Epoch 45, Loss: 205.46498107910156, Learning Rate: 6.25e-05
# Epoch 46, Loss: 309.3918762207031, Learning Rate: 6.25e-05
# Epoch 47, Loss: 173.00033569335938, Learning Rate: 6.25e-05
# Epoch 48, Loss: 204.23001098632812, Learning Rate: 6.25e-05
# Epoch 49, Loss: 265.4365539550781, Learning Rate: 6.25e-05
# Epoch 50, Loss: 195.50559997558594, Learning Rate: 1.5625e-05
# Epoch 51, Loss: 205.99588012695312, Learning Rate: 3.125e-05
# Epoch 52, Loss: 321.62286376953125, Learning Rate: 3.125e-05
# Epoch 53, Loss: 324.1454162597656, Learning Rate: 3.125e-05
# Epoch 54, Loss: 276.34527587890625, Learning Rate: 3.125e-05
# Epoch 55, Loss: 197.9891357421875, Learning Rate: 3.125e-05
# Epoch 56, Loss: 229.78958129882812, Learning Rate: 3.125e-05
# Epoch 57, Loss: 260.9383239746094, Learning Rate: 3.125e-05
# Epoch 58, Loss: 237.3812713623047, Learning Rate: 3.125e-05
# Epoch 59, Loss: 294.3672180175781, Learning Rate: 3.125e-05
# Epoch 60, Loss: 194.5288848876953, Learning Rate: 7.8125e-06
# Epoch 61, Loss: 314.3470458984375, Learning Rate: 1.5625e-05
# Epoch 62, Loss: 229.34422302246094, Learning Rate: 1.5625e-05
# Epoch 63, Loss: 185.0209503173828, Learning Rate: 1.5625e-05
# Epoch 64, Loss: 323.2180480957031, Learning Rate: 1.5625e-05
# Epoch 65, Loss: 255.67210388183594, Learning Rate: 1.5625e-05
# Epoch 66, Loss: 365.85369873046875, Learning Rate: 1.5625e-05
# Epoch 67, Loss: 184.72723388671875, Learning Rate: 1.5625e-05
# Epoch 68, Loss: 277.2637939453125, Learning Rate: 1.5625e-05
# Epoch 69, Loss: 228.8942108154297, Learning Rate: 1.5625e-05
# Epoch 70, Loss: 288.5958557128906, Learning Rate: 3.90625e-06
# Epoch 71, Loss: 345.153564453125, Learning Rate: 7.8125e-06
# Epoch 72, Loss: 190.432861328125, Learning Rate: 7.8125e-06
# Epoch 73, Loss: 387.4342956542969, Learning Rate: 7.8125e-06
# Epoch 74, Loss: 241.1416015625, Learning Rate: 7.8125e-06
# Epoch 75, Loss: 367.79388427734375, Learning Rate: 7.8125e-06
# Epoch 76, Loss: 300.9796447753906, Learning Rate: 7.8125e-06
# Epoch 77, Loss: 202.68215942382812, Learning Rate: 7.8125e-06
# Epoch 78, Loss: 331.2929992675781, Learning Rate: 7.8125e-06
# Epoch 79, Loss: 194.90536499023438, Learning Rate: 7.8125e-06
# Epoch 80, Loss: 252.17039489746094, Learning Rate: 1.953125e-06
# Epoch 81, Loss: 277.8922424316406, Learning Rate: 3.90625e-06
# Epoch 82, Loss: 237.51165771484375, Learning Rate: 3.90625e-06
# Epoch 83, Loss: 232.38247680664062, Learning Rate: 3.90625e-06
# Epoch 84, Loss: 206.9794921875, Learning Rate: 3.90625e-06
# Epoch 85, Loss: 298.435546875, Learning Rate: 3.90625e-06
# Epoch 86, Loss: 254.16741943359375, Learning Rate: 3.90625e-06
# Epoch 87, Loss: 174.42236328125, Learning Rate: 3.90625e-06
# Epoch 88, Loss: 186.79104614257812, Learning Rate: 3.90625e-06
# Epoch 89, Loss: 330.26910400390625, Learning Rate: 3.90625e-06
# Epoch 90, Loss: 230.892822265625, Learning Rate: 9.765625e-07
# Original Images
# Reconstructed Images
# Epoch 1, Loss: 1423.3876953125, Learning Rate: 0.001
# Epoch 2, Loss: 735.1366577148438, Learning Rate: 0.001
# Epoch 3, Loss: 707.5040283203125, Learning Rate: 0.001
# Epoch 4, Loss: 561.6406860351562, Learning Rate: 0.001
# Epoch 5, Loss: 555.0960083007812, Learning Rate: 0.001
# Epoch 6, Loss: 558.239013671875, Learning Rate: 0.001
# Epoch 7, Loss: 515.1920776367188, Learning Rate: 0.001
# Epoch 8, Loss: 536.0191650390625, Learning Rate: 0.001
# Epoch 9, Loss: 621.5567016601562, Learning Rate: 0.001
# Epoch 10, Loss: 549.774658203125, Learning Rate: 0.00025
# Epoch 11, Loss: 455.27923583984375, Learning Rate: 0.0005
# Epoch 12, Loss: 466.2587585449219, Learning Rate: 0.0005
# Epoch 13, Loss: 650.7086181640625, Learning Rate: 0.0005
# Epoch 14, Loss: 561.6952514648438, Learning Rate: 0.0005
# Epoch 15, Loss: 511.3456115722656, Learning Rate: 0.0005
# Epoch 16, Loss: 441.6124267578125, Learning Rate: 0.0005
# Epoch 17, Loss: 456.1242370605469, Learning Rate: 0.0005
# Epoch 18, Loss: 488.41070556640625, Learning Rate: 0.0005
# Epoch 19, Loss: 443.66339111328125, Learning Rate: 0.0005
# Epoch 20, Loss: 422.14959716796875, Learning Rate: 0.000125
# Epoch 21, Loss: 524.4895629882812, Learning Rate: 0.00025
# Epoch 22, Loss: 530.7855224609375, Learning Rate: 0.00025
# Epoch 23, Loss: 476.21124267578125, Learning Rate: 0.00025
# Epoch 24, Loss: 429.1665344238281, Learning Rate: 0.00025
# Epoch 25, Loss: 488.9430236816406, Learning Rate: 0.00025
# Epoch 26, Loss: 400.533935546875, Learning Rate: 0.00025
# Epoch 27, Loss: 401.3354797363281, Learning Rate: 0.00025
# Epoch 28, Loss: 445.4801940917969, Learning Rate: 0.00025
# Epoch 29, Loss: 390.79302978515625, Learning Rate: 0.00025
# Epoch 30, Loss: 489.3597106933594, Learning Rate: 6.25e-05
# Epoch 31, Loss: 466.5470275878906, Learning Rate: 0.000125
# Epoch 32, Loss: 419.8324279785156, Learning Rate: 0.000125
# Epoch 33, Loss: 413.1339416503906, Learning Rate: 0.000125
# Epoch 34, Loss: 449.8616638183594, Learning Rate: 0.000125
# Epoch 35, Loss: 405.40252685546875, Learning Rate: 0.000125
# Epoch 36, Loss: 462.7832336425781, Learning Rate: 0.000125
# Epoch 37, Loss: 439.0045166015625, Learning Rate: 0.000125
# Epoch 38, Loss: 401.5185241699219, Learning Rate: 0.000125
# Epoch 39, Loss: 419.701416015625, Learning Rate: 0.000125
# Epoch 40, Loss: 403.4127197265625, Learning Rate: 3.125e-05
# Epoch 41, Loss: 399.7251281738281, Learning Rate: 6.25e-05
# Epoch 42, Loss: 420.39892578125, Learning Rate: 6.25e-05
# Epoch 43, Loss: 378.12841796875, Learning Rate: 6.25e-05
# Epoch 44, Loss: 438.47613525390625, Learning Rate: 6.25e-05
# Epoch 45, Loss: 412.4686279296875, Learning Rate: 6.25e-05
# Epoch 46, Loss: 472.5181884765625, Learning Rate: 6.25e-05
# Epoch 47, Loss: 354.9217224121094, Learning Rate: 6.25e-05
# Epoch 48, Loss: 456.5431213378906, Learning Rate: 6.25e-05
# Epoch 49, Loss: 447.0509033203125, Learning Rate: 6.25e-05
# Epoch 50, Loss: 404.56298828125, Learning Rate: 1.5625e-05
# Epoch 51, Loss: 419.41937255859375, Learning Rate: 3.125e-05
# Epoch 52, Loss: 393.64520263671875, Learning Rate: 3.125e-05
# Epoch 53, Loss: 383.25244140625, Learning Rate: 3.125e-05
# Epoch 54, Loss: 407.09259033203125, Learning Rate: 3.125e-05
# Epoch 55, Loss: 394.5098876953125, Learning Rate: 3.125e-05
# Epoch 56, Loss: 399.05914306640625, Learning Rate: 3.125e-05
# Epoch 57, Loss: 447.9560241699219, Learning Rate: 3.125e-05
# Epoch 58, Loss: 398.5142822265625, Learning Rate: 3.125e-05
# Epoch 59, Loss: 418.89117431640625, Learning Rate: 3.125e-05
# Epoch 60, Loss: 430.1533508300781, Learning Rate: 7.8125e-06
# Epoch 61, Loss: 501.34552001953125, Learning Rate: 1.5625e-05
# Epoch 62, Loss: 390.31280517578125, Learning Rate: 1.5625e-05
# Epoch 63, Loss: 420.7048034667969, Learning Rate: 1.5625e-05
# Epoch 64, Loss: 401.83251953125, Learning Rate: 1.5625e-05
# Epoch 65, Loss: 425.3904113769531, Learning Rate: 1.5625e-05
# Epoch 66, Loss: 412.28961181640625, Learning Rate: 1.5625e-05
# Epoch 67, Loss: 443.5265808105469, Learning Rate: 1.5625e-05
# Epoch 68, Loss: 439.97454833984375, Learning Rate: 1.5625e-05
# Epoch 69, Loss: 425.51995849609375, Learning Rate: 1.5625e-05
# Epoch 70, Loss: 375.7945556640625, Learning Rate: 3.90625e-06
# Epoch 71, Loss: 409.4398193359375, Learning Rate: 7.8125e-06
# Epoch 72, Loss: 401.672607421875, Learning Rate: 7.8125e-06
# Epoch 73, Loss: 374.82818603515625, Learning Rate: 7.8125e-06
# Epoch 74, Loss: 425.662109375, Learning Rate: 7.8125e-06
# Epoch 75, Loss: 450.1024169921875, Learning Rate: 7.8125e-06
# Epoch 76, Loss: 420.0341491699219, Learning Rate: 7.8125e-06
# Epoch 77, Loss: 403.3335876464844, Learning Rate: 7.8125e-06
# Epoch 78, Loss: 406.5645446777344, Learning Rate: 7.8125e-06
# Epoch 79, Loss: 405.6408996582031, Learning Rate: 7.8125e-06
# Epoch 80, Loss: 425.67510986328125, Learning Rate: 1.953125e-06
# Epoch 81, Loss: 423.94329833984375, Learning Rate: 3.90625e-06
# Epoch 82, Loss: 414.27069091796875, Learning Rate: 3.90625e-06
# Epoch 83, Loss: 431.9205627441406, Learning Rate: 3.90625e-06
# Epoch 84, Loss: 423.6914367675781, Learning Rate: 3.90625e-06
# Epoch 85, Loss: 485.75311279296875, Learning Rate: 3.90625e-06
# Epoch 86, Loss: 362.9015808105469, Learning Rate: 3.90625e-06
# Epoch 87, Loss: 405.8629150390625, Learning Rate: 3.90625e-06
# Epoch 88, Loss: 420.87127685546875, Learning Rate: 3.90625e-06
# Epoch 89, Loss: 443.6636962890625, Learning Rate: 3.90625e-06
# Epoch 90, Loss: 401.7978515625, Learning Rate: 9.765625e-07
# Original Images
# Reconstructed Images
# Epoch 1, Loss: 5659.38427734375, Learning Rate: 0.001
# Epoch 2, Loss: 1839.754638671875, Learning Rate: 0.001
# Epoch 3, Loss: 1194.2349853515625, Learning Rate: 0.001
# Epoch 4, Loss: 824.927734375, Learning Rate: 0.001
# Epoch 5, Loss: 802.2767944335938, Learning Rate: 0.001
# Epoch 6, Loss: 798.4125366210938, Learning Rate: 0.001
# Epoch 7, Loss: 800.560546875, Learning Rate: 0.001
# Epoch 8, Loss: 685.3396606445312, Learning Rate: 0.001
# Epoch 9, Loss: 666.285400390625, Learning Rate: 0.001
# Epoch 10, Loss: 785.357666015625, Learning Rate: 0.00025
# Epoch 11, Loss: 662.3614501953125, Learning Rate: 0.0005
# Epoch 12, Loss: 695.5231323242188, Learning Rate: 0.0005
# Epoch 13, Loss: 639.56884765625, Learning Rate: 0.0005
# Epoch 14, Loss: 573.5297241210938, Learning Rate: 0.0005
# Epoch 15, Loss: 675.00244140625, Learning Rate: 0.0005
# Epoch 16, Loss: 610.2825317382812, Learning Rate: 0.0005
# Epoch 17, Loss: 616.6202392578125, Learning Rate: 0.0005
# Epoch 18, Loss: 610.0497436523438, Learning Rate: 0.0005
# Epoch 19, Loss: 578.4161987304688, Learning Rate: 0.0005
# Epoch 20, Loss: 599.5143432617188, Learning Rate: 0.000125
# Epoch 21, Loss: 489.4799499511719, Learning Rate: 0.00025
# Epoch 22, Loss: 369.0505065917969, Learning Rate: 0.00025
# Epoch 23, Loss: 402.84979248046875, Learning Rate: 0.00025
# Epoch 24, Loss: 313.10638427734375, Learning Rate: 0.00025
# Epoch 25, Loss: 322.7895812988281, Learning Rate: 0.00025
# Epoch 26, Loss: 318.0383605957031, Learning Rate: 0.00025
# Epoch 27, Loss: 310.04095458984375, Learning Rate: 0.00025
# Epoch 28, Loss: 283.65252685546875, Learning Rate: 0.00025
# Epoch 29, Loss: 300.22625732421875, Learning Rate: 0.00025
# Epoch 30, Loss: 308.46820068359375, Learning Rate: 6.25e-05
# Epoch 31, Loss: 280.7755126953125, Learning Rate: 0.000125
# Epoch 32, Loss: 237.54013061523438, Learning Rate: 0.000125
# Epoch 33, Loss: 293.1373596191406, Learning Rate: 0.000125
# Epoch 34, Loss: 256.23663330078125, Learning Rate: 0.000125
# Epoch 35, Loss: 259.02008056640625, Learning Rate: 0.000125
# Epoch 36, Loss: 281.5238342285156, Learning Rate: 0.000125
# Epoch 37, Loss: 250.97848510742188, Learning Rate: 0.000125
# Epoch 38, Loss: 267.4626770019531, Learning Rate: 0.000125
# Epoch 39, Loss: 250.2706298828125, Learning Rate: 0.000125
# Epoch 40, Loss: 250.86831665039062, Learning Rate: 3.125e-05
# Epoch 41, Loss: 250.57891845703125, Learning Rate: 6.25e-05
# Epoch 42, Loss: 246.98724365234375, Learning Rate: 6.25e-05
# Epoch 43, Loss: 267.6146545410156, Learning Rate: 6.25e-05
# Epoch 44, Loss: 252.60223388671875, Learning Rate: 6.25e-05
# Epoch 45, Loss: 250.4876708984375, Learning Rate: 6.25e-05
# Epoch 46, Loss: 279.5389099121094, Learning Rate: 6.25e-05
# Epoch 47, Loss: 253.14498901367188, Learning Rate: 6.25e-05
# Epoch 48, Loss: 268.9391174316406, Learning Rate: 6.25e-05
# Epoch 49, Loss: 246.8486328125, Learning Rate: 6.25e-05
# Epoch 50, Loss: 215.84088134765625, Learning Rate: 1.5625e-05
# Epoch 51, Loss: 266.9265441894531, Learning Rate: 3.125e-05
# Epoch 52, Loss: 228.25372314453125, Learning Rate: 3.125e-05
# Epoch 53, Loss: 233.83615112304688, Learning Rate: 3.125e-05
# Epoch 54, Loss: 256.89154052734375, Learning Rate: 3.125e-05
# Epoch 55, Loss: 212.89077758789062, Learning Rate: 3.125e-05
# Epoch 56, Loss: 250.09376525878906, Learning Rate: 3.125e-05
# Epoch 57, Loss: 254.85940551757812, Learning Rate: 3.125e-05
# Epoch 58, Loss: 264.0438537597656, Learning Rate: 3.125e-05
# Epoch 59, Loss: 219.86834716796875, Learning Rate: 3.125e-05
# Epoch 60, Loss: 236.679443359375, Learning Rate: 7.8125e-06
# Epoch 61, Loss: 225.75894165039062, Learning Rate: 1.5625e-05
# Epoch 62, Loss: 249.12576293945312, Learning Rate: 1.5625e-05
# Epoch 63, Loss: 239.326416015625, Learning Rate: 1.5625e-05
# Epoch 64, Loss: 254.4131317138672, Learning Rate: 1.5625e-05
# Epoch 65, Loss: 229.07423400878906, Learning Rate: 1.5625e-05
# Epoch 66, Loss: 240.99032592773438, Learning Rate: 1.5625e-05
# Epoch 67, Loss: 291.8349914550781, Learning Rate: 1.5625e-05
# Epoch 68, Loss: 224.90798950195312, Learning Rate: 1.5625e-05
# Epoch 69, Loss: 232.0739288330078, Learning Rate: 1.5625e-05
# Epoch 70, Loss: 208.09291076660156, Learning Rate: 3.90625e-06
# Epoch 71, Loss: 210.17623901367188, Learning Rate: 7.8125e-06
# Epoch 72, Loss: 230.23886108398438, Learning Rate: 7.8125e-06
# Epoch 73, Loss: 229.03704833984375, Learning Rate: 7.8125e-06
# Epoch 74, Loss: 247.91055297851562, Learning Rate: 7.8125e-06
# Epoch 75, Loss: 219.39959716796875, Learning Rate: 7.8125e-06
# Epoch 76, Loss: 235.65798950195312, Learning Rate: 7.8125e-06
# Epoch 77, Loss: 216.7249755859375, Learning Rate: 7.8125e-06
# Epoch 78, Loss: 240.86666870117188, Learning Rate: 7.8125e-06
# Epoch 79, Loss: 245.05126953125, Learning Rate: 7.8125e-06
# Epoch 80, Loss: 246.01284790039062, Learning Rate: 1.953125e-06
# Epoch 81, Loss: 279.3421325683594, Learning Rate: 3.90625e-06
# Epoch 82, Loss: 224.92129516601562, Learning Rate: 3.90625e-06
# Epoch 83, Loss: 231.91461181640625, Learning Rate: 3.90625e-06
# Epoch 84, Loss: 240.25421142578125, Learning Rate: 3.90625e-06
# Epoch 85, Loss: 245.30801391601562, Learning Rate: 3.90625e-06
# Epoch 86, Loss: 203.21533203125, Learning Rate: 3.90625e-06
# Epoch 87, Loss: 235.30123901367188, Learning Rate: 3.90625e-06
# Epoch 88, Loss: 223.10989379882812, Learning Rate: 3.90625e-06
# Epoch 89, Loss: 230.0848388671875, Learning Rate: 3.90625e-06
# Epoch 90, Loss: 248.7440643310547, Learning Rate: 9.765625e-07
# Original Images
# Reconstructed Images
# Epoch 1, Loss: 4268.30517578125, Learning Rate: 0.001
# Epoch 2, Loss: 1907.4208984375, Learning Rate: 0.001
# Epoch 3, Loss: 1698.122802734375, Learning Rate: 0.001
# Epoch 4, Loss: 1255.3330078125, Learning Rate: 0.001
# Epoch 5, Loss: 1388.430419921875, Learning Rate: 0.001
# Epoch 6, Loss: 980.584228515625, Learning Rate: 0.001
# Epoch 7, Loss: 1444.954345703125, Learning Rate: 0.001
# Epoch 8, Loss: 1152.0543212890625, Learning Rate: 0.001
# Epoch 9, Loss: 1063.9603271484375, Learning Rate: 0.001
# Epoch 10, Loss: 493.69329833984375, Learning Rate: 0.00025
# Epoch 11, Loss: 665.0438232421875, Learning Rate: 0.0005
# Epoch 12, Loss: 778.0271606445312, Learning Rate: 0.0005
# Epoch 13, Loss: 859.3685913085938, Learning Rate: 0.0005
# Epoch 14, Loss: 640.0493774414062, Learning Rate: 0.0005
# Epoch 15, Loss: 613.2075805664062, Learning Rate: 0.0005
# Epoch 16, Loss: 472.39471435546875, Learning Rate: 0.0005
# Epoch 17, Loss: 551.03125, Learning Rate: 0.0005
# Epoch 18, Loss: 740.2459716796875, Learning Rate: 0.0005
# Epoch 19, Loss: 559.3367919921875, Learning Rate: 0.0005
# Epoch 20, Loss: 637.2095947265625, Learning Rate: 0.000125
# Epoch 21, Loss: 583.2467651367188, Learning Rate: 0.00025
# Epoch 22, Loss: 489.93145751953125, Learning Rate: 0.00025
# Epoch 23, Loss: 542.98095703125, Learning Rate: 0.00025
# Epoch 24, Loss: 717.8382568359375, Learning Rate: 0.00025
# Epoch 25, Loss: 686.7227783203125, Learning Rate: 0.00025
# Epoch 26, Loss: 445.5964660644531, Learning Rate: 0.00025
# Epoch 27, Loss: 459.358642578125, Learning Rate: 0.00025
# Epoch 28, Loss: 747.9515380859375, Learning Rate: 0.00025
# Epoch 29, Loss: 549.94091796875, Learning Rate: 0.00025
# Epoch 30, Loss: 616.5309448242188, Learning Rate: 6.25e-05
# Epoch 31, Loss: 546.8192749023438, Learning Rate: 0.000125
# Epoch 32, Loss: 522.3931884765625, Learning Rate: 0.000125
# Epoch 33, Loss: 499.9520263671875, Learning Rate: 0.000125
# Epoch 34, Loss: 458.927490234375, Learning Rate: 0.000125
# Epoch 35, Loss: 456.77838134765625, Learning Rate: 0.000125
# Epoch 36, Loss: 493.2918701171875, Learning Rate: 0.000125
# Epoch 37, Loss: 414.4753723144531, Learning Rate: 0.000125
# Epoch 38, Loss: 580.4680786132812, Learning Rate: 0.000125
# Epoch 39, Loss: 576.8939819335938, Learning Rate: 0.000125
# Epoch 40, Loss: 398.17864990234375, Learning Rate: 3.125e-05
# Epoch 41, Loss: 406.2680358886719, Learning Rate: 6.25e-05
# Epoch 42, Loss: 503.6268005371094, Learning Rate: 6.25e-05
# Epoch 43, Loss: 409.0824890136719, Learning Rate: 6.25e-05
# Epoch 44, Loss: 384.15655517578125, Learning Rate: 6.25e-05
# Epoch 45, Loss: 296.2815856933594, Learning Rate: 6.25e-05
# Epoch 46, Loss: 558.0725708007812, Learning Rate: 6.25e-05
# Epoch 47, Loss: 463.81341552734375, Learning Rate: 6.25e-05
# Epoch 48, Loss: 485.438720703125, Learning Rate: 6.25e-05
# Epoch 49, Loss: 478.2141418457031, Learning Rate: 6.25e-05
# Epoch 50, Loss: 632.6446533203125, Learning Rate: 1.5625e-05
# Epoch 51, Loss: 521.1537475585938, Learning Rate: 3.125e-05
# Epoch 52, Loss: 554.3421630859375, Learning Rate: 3.125e-05
# Epoch 53, Loss: 471.8936767578125, Learning Rate: 3.125e-05
# Epoch 54, Loss: 416.0291748046875, Learning Rate: 3.125e-05
# Epoch 55, Loss: 463.46868896484375, Learning Rate: 3.125e-05
# Epoch 56, Loss: 599.700927734375, Learning Rate: 3.125e-05
# Epoch 57, Loss: 423.5022277832031, Learning Rate: 3.125e-05
# Epoch 58, Loss: 419.1197814941406, Learning Rate: 3.125e-05
# Epoch 59, Loss: 503.35015869140625, Learning Rate: 3.125e-05
# Epoch 60, Loss: 437.3136291503906, Learning Rate: 7.8125e-06
# Epoch 61, Loss: 474.99322509765625, Learning Rate: 1.5625e-05
# Epoch 62, Loss: 379.2021484375, Learning Rate: 1.5625e-05
# Epoch 63, Loss: 525.7528076171875, Learning Rate: 1.5625e-05
# Epoch 64, Loss: 508.89544677734375, Learning Rate: 1.5625e-05
# Epoch 65, Loss: 440.9173889160156, Learning Rate: 1.5625e-05
# Epoch 66, Loss: 372.36090087890625, Learning Rate: 1.5625e-05
# Epoch 67, Loss: 442.646240234375, Learning Rate: 1.5625e-05
# Epoch 68, Loss: 492.3623046875, Learning Rate: 1.5625e-05
# Epoch 69, Loss: 259.93511962890625, Learning Rate: 1.5625e-05
# Epoch 70, Loss: 428.28472900390625, Learning Rate: 3.90625e-06
# Epoch 71, Loss: 442.56207275390625, Learning Rate: 7.8125e-06
# Epoch 72, Loss: 201.69456481933594, Learning Rate: 7.8125e-06
# Epoch 73, Loss: 584.1124267578125, Learning Rate: 7.8125e-06
# Epoch 74, Loss: 563.7395629882812, Learning Rate: 7.8125e-06
# Epoch 75, Loss: 414.7295837402344, Learning Rate: 7.8125e-06
# Epoch 76, Loss: 421.13909912109375, Learning Rate: 7.8125e-06
# Epoch 77, Loss: 513.6728515625, Learning Rate: 7.8125e-06
# Epoch 78, Loss: 416.2459411621094, Learning Rate: 7.8125e-06
# Epoch 79, Loss: 560.4291381835938, Learning Rate: 7.8125e-06
# Epoch 80, Loss: 426.3272705078125, Learning Rate: 1.953125e-06
# Epoch 81, Loss: 402.7423095703125, Learning Rate: 3.90625e-06
# Epoch 82, Loss: 462.17498779296875, Learning Rate: 3.90625e-06
# Epoch 83, Loss: 419.7240905761719, Learning Rate: 3.90625e-06
# Epoch 84, Loss: 328.20751953125, Learning Rate: 3.90625e-06
# Epoch 85, Loss: 444.1050720214844, Learning Rate: 3.90625e-06
# Epoch 86, Loss: 502.60040283203125, Learning Rate: 3.90625e-06
# Epoch 87, Loss: 344.92083740234375, Learning Rate: 3.90625e-06
# Epoch 88, Loss: 420.8711242675781, Learning Rate: 3.90625e-06
# Epoch 89, Loss: 413.6886291503906, Learning Rate: 3.90625e-06
# Epoch 90, Loss: 503.1003112792969, Learning Rate: 9.765625e-07
# Original Images
# Reconstructed Images
